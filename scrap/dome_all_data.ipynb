# %%
import time
import pandas as pd
import re
import os
import openpyxl

# %%
#AT_TSALET_ALL_201601
for year in range(2016,2021):
    for month in range()
    print(year)
list_item_name=[]

# %%
#파일들 합치기

for item in list_item_name:
    Temp_data=[]
    for area in list_area_name:
        file_name='../files/전체/'+area+'-'+item+'.xls'
        try:
            Temp_data.append(pd.read_excel(file_name))
        except FileNotFoundError as e:
            #국제수산처럼, 파일이 없는 경우.
            continue
    file_name='../files/도매시장/'+item+'.xlsx'
    pd.concat(Temp_data).to_excel(file_name,index=False)

# %%
data=pd.read_csv('../files/전처리/AT_TSALET_ALL_201601.csv')

# %%
print(len(data))
data.head()
# Out:
# 2700796
#    SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 0  20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# 1  20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
# 2  20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .     특
# 3  20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .     특
# 4  20160109   부산엄궁도매   부산청과     감귤     조생귤     kg     상자       .    보통
#
#     SAN_NM  DANQ  QTY     COST  TOT_QTY  TOT_AMT
# 0  제주도 제주시  10.0   62  14400.0    620.0   892800
# 1  제주도 제주시  10.0   29  14700.0    290.0   426300
# 2  제주도 제주시  10.0   17  12800.0    170.0   217600
# 3  제주도 제주시  10.0   16   8800.0    160.0   140800
# 4  제주 남제주군  10.0   25   7300.0    250.0   182500

# %%
data["PUM_NM"].unique()
# Out:
# array(['감귤', '만감', '오이', '쪽파', '브로코리(녹색꽃양배추)', '적채', '콜라비(순무양배추)', '고구마',
#        '감자', '대파', '호박', '딸기', '칼리플라워(꽃양배추)', '비트(붉은사탕무우)', '배추', '기타',
#        '부추', '무', '미나리', '양파', '우엉', '사과', '시금치', '쑥', '양상추', '상추',
#        '피망(단고추)', '가지', '오렌지', '레몬', '방아', '봄동배추', '열무', '참나물', '머위대',
#        '동초', '냉이', '토마토', '풋고추', '홍고추', '돗나물', '로메인', '청경채', '치커리', '근대',
#        '케일', '새송이', '팽이버섯', '만가닥', '느타리버섯', '생강', '마늘', '방울토마토', '꽈리고추',
#        '수박', '단감', '양송이', '표고버섯', '곶감', '쑥갓', '파세리(향미나리)', '셀러리(양미나리)',
#        '깻잎', '겨자채', '마', '연근', '도라지', '미역', '우뭇가사리', '취나물', '비타민', '새싹',
#        '파프리카', '당근', '양배추', '고수', '얼갈이배추', '유채', '달래', '고비', '고사리',
#        '조미제품', '곡물제조', '고구마순', '토란대', '갓', '무순', '전분 및 사료제조', '콩나물',
#        '숙주나물', '계피', '목이', '참깨', '바나나', '파인애플', '유지', '대추', '절임식품',
#        '조미가공', '다시마', '파래', '어묵_어분_어비', '차', '황기', '과루인(하늘타리)', '포도',
#        '아욱', '밤', '떫은감', '배', '겨자', '참당귀', '쌈추', '방울양배추(스프로스)', '속새',
# ...

# %%
options = ['배추', '무', '갓','미나리','쪽파','생강','마늘']
  
# selecting rows based on condition
select_data = data[data['PUM_NM'].isin(options)]

print(len(select_data))
select_data.head()
#이제 파일들 읽어서 저장하는걸로 바꿔야함.
# Out:
# 112969
#      SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 44   20160109   부산엄궁도매   부산청과     쪽파     깐쪽파     kg      단       .    보통
# 151  20160109   부산엄궁도매   부산청과     쪽파     깐쪽파     kg      단       .    보통
# 152  20160109   부산엄궁도매   부산청과     쪽파     깐쪽파     kg      단       .    보통
# 153  20160109   부산엄궁도매   부산청과     쪽파     깐쪽파     kg      단       .    보통
# 154  20160109   부산엄궁도매   부산청과     쪽파     깐쪽파     kg      단       .    보통
#
#       SAN_NM  DANQ  QTY    COST  TOT_QTY  TOT_AMT
# 44   제주도 제주시   1.0   10  5880.0     10.0    58800
# 151  제주 북제주군   1.0   50  5570.0     50.0   278500
# 152  제주 북제주군   1.0   50  5880.0     50.0   294000
# 153  제주 북제주군   1.0   40  5150.0     40.0   206000
# 154  제주 북제주군   1.0   20  4700.0     20.0    94000

# %%
select_data.isna().sum()
# Out:
# SALEDATE       0
# WHSAL_NM       0
# CMP_NM         0
# PUM_NM         0
# KIND_NM        0
# DAN_NM         0
# POJ_NM       140
# SIZE_NM     2040
# LV_NM          0
# SAN_NM      2757
# DANQ           0
# QTY            0
# COST           0
# TOT_QTY        0
# TOT_AMT        0
# dtype: int64

# %%
#법인 버리기
#minari.drop(['법인'], axis=1, inplace=True)

#날짜 바꾸기
pd.to_datetime(data['SALEDATE'], format='%Y%m%d')
#일자 소팅
# Out:
# 0         2016-01-09
# 1         2016-01-09
# 2         2016-01-09
# 3         2016-01-09
# 4         2016-01-09
#              ...
# 2700791   2016-01-30
# 2700792   2016-01-30
# 2700793   2016-01-30
# 2700794   2016-01-30
# 2700795   2016-01-30
# Name: SALEDATE, Length: 2700796, dtype: datetime64[ns]

# %%
data[data['PUM_NM']=='배추']
# Out:
#          SALEDATE WHSAL_NM CMP_NM PUM_NM KIND_NM DAN_NM POJ_NM SIZE_NM LV_NM  \
# 165      20160109   부산엄궁도매   부산청과     배추     쌈배추     kg     상자       .    보통
# 262      20160109   부산엄궁도매   부산청과     배추     쌈배추     kg     상자       .    보통
# 263      20160109   부산엄궁도매   부산청과     배추     쌈배추     kg     상자       .    보통
# 325      20160109   부산엄궁도매   부산청과     배추    기타배추     kg      단       .    보통
# 434      20160109   부산엄궁도매   부산청과     배추    기타배추     kg    그물망       .    보통
# ...           ...      ...    ...    ...     ...    ...    ...     ...   ...
# 2700717  20160130   서울강서도매   강서청과     배추    기타배추     kg      접       .     .
# 2700718  20160130   서울강서도매   강서청과     배추    기타배추     kg      접       .     .
# 2700719  20160130   서울강서도매   강서청과     배추    기타배추     kg      접       .     .
# 2700720  20160130   서울강서도매   강서청과     배추    기타배추     kg      접       .     .
# 2700721  20160130   서울강서도매   강서청과     배추    기타배추     kg      접       .     .
#
# ...
